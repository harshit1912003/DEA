# %%
from models.modelsDEA import DEA
from models.modelsFDH import FDH
import numpy as np
from utils.is_efficient import is_efficient
import matplot2lib.pyplot as plt
from utils.datainput import initializeUnif

# %%
inp, outp = initializeUnif(60, 1, 1, 1, 20)

# %%
dea = DEA(inp, outp)
fdh = FDH(inp, outp)

# %%
dea.plot_with_frontier("ccr_input")
# Out:
# Calculating results for ccr_input...
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2579375
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in

# %%
dea.plot_with_frontier("bcc_input")
# Out:
# Calculating results for bcc_input...

# %%
fdh.plot_fdh("fdh_input_vrs")
# Out:
# Calculating results for fdh_input_vrs...

# %%
fdh.fdh_output_vrs()
# Out:
#     DMU  efficiency  is_efficient
# 0     0    2.254337         False
# 1     1    2.105275         False
# 2     2    1.691002         False
# 3     3    1.083004         False
# 4     4    1.991361         False
# 5     5    3.849434         False
# 6     6    1.806930         False
# 7     7    1.967970         False
# 8     8    1.673184         False
# 9     9    1.725097         False
# 10   10    1.228880         False
# 11   11    5.788065         False
# 12   12    2.573413         False
# 13   13   11.986375         False
# 14   14    5.096304         False
# 15   15   16.835206         False
# 16   16    1.249665         False
# 17   17    1.785477         False
# 18   18    1.181560         False
# 19   19    2.538884         False
# 20   20    1.331993         False
# 21   21    1.000000          True
# 22   22    6.881876         False
# 23   23    1.245722         False
# 24   24    4.573269         False
# 25   25    1.471885         False
# ...
