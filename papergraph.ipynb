# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'DMU': range(1, 33),
    'E': [0.5894, 0.6515, 0.6002, 0.6348, 0.5936, 0.6408, 0.9527, 0.7828, 0.8428, 0.8397, 0.7562, 0.6849, 0.6894, 0.6621, 0.9482, 0.8832, 0.8868, 0.8616, 1.0000, 1.0000, 1.0000, 1.0000, 0.7198, 0.9426, 0.9777, 0.7197, 0.6718, 0.5903, 0.7477, 0.5090, 0.4237, 1.0000],
    'CR': [0.4138, 0.5086, 0.4772, 0.4862, 0.4971, 0.4525, 1.0000, 0.4679, 0.5199, 0.5300, 0.5259, 0.5170, 0.3865, 0.4698, 0.5157, 0.5154, 0.5118, 0.5184, 0.6093, 0.5316, 1.0000, 1.0000, 0.3219, 1.0000, 0.6406, 0.4588, 0.4159, 1.0000, 0.3233, 0.2799, 0.2449, 0.5537],
    'NCR': [0.5341, 0.5625, 0.5347, 0.5268, 0.5880, 0.5418, 1.0000, 0.5417, 0.5288, 0.5938, 0.5625, 0.5417, 0.4746, 0.5375, 0.5234, 0.5375, 0.5208, 0.5313, 0.6875, 0.5938, 1.0000, 1.0000, 0.9600, 1.0000, 1.0000, 0.6857, 0.9250, 1.0000, 1.0000, 0.5360, 0.5114, 1.0000],
    'NCRE': [0.3339, 0.4716, 0.3589, 0.4000, 0.4583, 0.3183, 1.0000, 0.3750, 0.7846, 0.4271, 0.4196, 0.5417, 0.2641, 0.3405, 0.7386, 0.5375, 0.5355, 0.7148, 0.6875, 0.5938, 0.6618, 1.0000, 0.6517, 0.9000, 0.6798, 0.4211, 0.3333, 0.4412, 0.9782, 0.4640, 0.5294, 1.0000],
    'CRE': [0.2920, 0.4185, 0.2994, 0.3402, 0.4583, 0.3082, 1.0000, 0.3129, 0.4861, 0.4271, 0.3822, 0.4397, 0.2454, 0.3405, 0.5390, 0.5375, 0.4227, 0.6317, 0.6875, 0.5092, 0.5617, 0.7699, 0.3977, 0.9000, 0.3827, 0.3125, 0.2583, 0.3063, 0.5561, 0.3041, 0.2744, 1.0000],
}

df = pd.DataFrame(data)

df.set_index('DMU', inplace=True)

plt.figure(figsize=(10, 6))

plt.plot(df.index, df['E'], label='E', marker='o')
plt.plot(df.index, df['CR'], label='CR', marker='x')
plt.plot(df.index, df['NCR'], label='NCR', marker='s')
plt.plot(df.index, df['NCRE'], label='NCRE', marker='D')
plt.plot(df.index, df['CRE'], label='CRE', marker='H')

plt.xlabel('DMU')
plt.ylabel('Efficiency Value')
plt.title('Efficiency Values of 32 DMUs')
plt.legend()

plt.grid(True)
plt.savefig('./plot.pdf', dpi=300)

plt.show()
